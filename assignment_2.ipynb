# %% [markdown]
# <a href="https://colab.research.google.com/github/Safwaahmad/Safwaahmad/blob/main/assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list=[10,20,30]
result = my_list[0]
print(result)
# Out:
# 10

# %%
my_list=[10,20,30]
my_list[0]=40
print(my_list)
# Out:
# [40, 20, 30]

# %%
my_list=[10,20,30]
result=my_list[-1]
print(result)
# Out:
# 30

# %%
object = 10
result = id(object)
print(result)
# Out:
# 136893700768272

# %%
my_list=[1,2,3,4,5]
ans=my_list.index(4)
print(ans)
# Out:
# 3

# %%
my_list=[1,2,3,4,5]
digits = my_list[2:5:2]
print(digits)
# Out:
# [3, 5]

# %%
my_list=[1,2,3,4,5]
my_list[1:4]= [7,8,9]
print(my_list)
# Out:
# [1, 7, 8, 9, 5]
